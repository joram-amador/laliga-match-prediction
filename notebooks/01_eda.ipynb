# %% [markdown]
# # Load Dataset

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("marcelbiezunski/laliga-matches-dataset-2019-2025-fbref")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 1.0.0)
# Downloading from https://www.kaggle.com/api/v1/datasets/download/marcelbiezunski/laliga-matches-dataset-2019-2025-fbref?dataset_version_number=3...
# 100%|██████████| 149k/149k [00:00<00:00, 54.6MB/s]
# Extracting model files...
# Path to dataset files: /Users/joramador/.cache/kagglehub/datasets/marcelbiezunski/laliga-matches-dataset-2019-2025-fbref/versions/3
